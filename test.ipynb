# %% [markdown]
# # CIL Road Segmentation Project 2020
# Group Roadtripper
#
#
# *   Tommaso
# *   Yihang
# *   Zhenhan
# *   Jonas
#
#
# ---

# %% [markdown]
# # Establishment of the working environment

# %%
# Import Colab libraries
from google.colab import drive
import os
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
# Mount Google Drive to virtual machine
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# Change directory to working folder
cd 'drive/My Drive/Daten/Jahr 2020/Studium/Semester 8/Computational Intelligence Lab/Road Segmentation Project/model/model 3.0'
# Out:
# /content/drive/My Drive/Daten/Jahr 2020/Studium/Semester 8/Computational Intelligence Lab/Road Segmentation Project/model/model 3.0

# %% [markdown]
# # Importing testing data

# %%
x_test = np.load("testing/x_test.npy")

# %%
# Print the shape of the array
print("x_test shape: " + str(x_test.shape))
# Out:
# x_test shape: (135736, 72, 72, 3)

# %% [markdown]
# # Load the trained model

# %%
# Recreate the exact same model, including its weights and the optimizer
model = tf.keras.models.load_model('weights.h5')
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
# Show the model architecture
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# 1_Convolution (Conv2D)       (None, 72, 72, 64)        4864
# _________________________________________________________________
# 1_Leaky (LeakyReLU)          (None, 72, 72, 64)        0
# _________________________________________________________________
# 1_MaxPooling (MaxPooling2D)  (None, 36, 36, 64)        0
# _________________________________________________________________
# 1_Dropout (Dropout)          (None, 36, 36, 64)        0
# _________________________________________________________________
# 2_Convolution (Conv2D)       (None, 36, 36, 128)       73856
# _________________________________________________________________
# 2_Leaky (LeakyReLU)          (None, 36, 36, 128)       0
# _________________________________________________________________
# 2_MaxPooling (MaxPooling2D)  (None, 18, 18, 128)       0
# _________________________________________________________________
# 2_Dropout (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# 3_Convolution (Conv2D)       (None, 18, 18, 256)       295168
# _________________________________________________________________
# 3_Leaky (LeakyReLU)          (None, 18, 18, 256)       0
# _________________________________________________________________
# 3_MaxPooling (MaxPooling2D)  (None, 9, 9, 256)         0
# _________________________________________________________________
# 3_Dropout (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# 4_Convolution (Conv2D)       (None, 9, 9, 256)         590080
# _________________________________________________________________
# 4_Leaky (LeakyReLU)          (None, 9, 9, 256)         0
# _________________________________________________________________
# 4_MaxPooling (MaxPooling2D)  (None, 5, 5, 256)         0
# _________________________________________________________________
# 4_Dropout (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# 5_Flatten (Flatten)          (None, 6400)              0
# _________________________________________________________________
# 5_Dense (Dense)              (None, 128)               819328
# _________________________________________________________________
# 5_Leaky (LeakyReLU)          (None, 128)               0
# _________________________________________________________________
# 5_Dropout (Dropout)          (None, 128)               0
# _________________________________________________________________
# 6_Dense (Dense)              (None, 2)                 258
# =================================================================
# Total params: 1,783,554
# Trainable params: 1,783,554
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Predict labels with model

# %%
y_test = model.predict(x_test)

# %%
print(y_test.shape)
print(y_test[569])
# Out:
# (135736, 2)
# [1. 0.]

# %%
y_test = np.argmax(y_test, axis=1)

# %% [markdown]
# # Save labels

# %%
pd.Series(y_test).to_csv("y_test.csv", header=False, index=False)
